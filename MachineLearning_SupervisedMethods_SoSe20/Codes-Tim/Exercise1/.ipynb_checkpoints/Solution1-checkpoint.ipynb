# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
image = np.load("workers/workers_x.npy")
label = np.load("workers/workers_y.npy")

# %%
def showimage(x):
    plt.imshow(x)
    plt.show()

# %%
image_legth=image.shape
vector_images=image.reshape(452,60000)

# %%
def perceptron( X_matrix, Y_vector, run_times, learning_rate):
    initial_vector=np.random.normal(loc=0.0, scale=0.1, size=60000)
    for i in range(0,run_times):
        for j in (N)
        initial_vector=initial_vector-learning_rate*(label-np.dot(X_matrix, initial_vector))

# %%
perceptron(vector_images, label, 10, 0.1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-c3cf2c3f92c9> in <module>()
# ----> 1 perceptron(vector_images, label, 10, 0.1)
#
# <ipython-input-108-f926bec6534c> in perceptron(X_matrix, Y_vector, run_times, learning_rate)
#       2     initial_vector=np.random.normal(loc=0.0, scale=0.1, size=60000)
#       3     for i in range(0,1):
# ----> 4         initial_vector=initial_vector-learning_rate*(label-np.dot(X_matrix, initial_vector))
#
# ValueError: operands could not be broadcast together with shapes (60000,) (452,)

# %%
np.dot(vector_images, initial_vector)-label
# Out:
# array([24.09594342, 22.76848016, 24.17010163, 26.67210843, 23.27836148,
#        25.16838211, 24.15734087, 26.45149975, 25.93632731, 25.86357585,
#        22.34466888, 22.47636954, 25.64778785, 25.11553859, 25.74402179,
#        24.4109523 , 24.14368697, 23.61606224, 23.88205678, 26.64373848,
#        22.86871495, 24.90227066, 25.92276383, 25.87768059, 22.89520991,
#        25.94464356, 25.63095617, 24.0195474 , 23.53167785, 24.96085556,
#        22.79433427, 26.53006281, 26.00437834, 27.4656053 , 25.87068433,
#        22.59750844, 22.62382481, 24.61906371, 25.39351975, 23.10706944,
#        24.73891337, 25.77710478, 25.68958307, 25.80891525, 26.51251399,
#        25.7919933 , 25.09563402, 25.06725348, 25.65191162, 24.20410843,
#        23.43398091, 22.7090772 , 24.91132493, 25.27675293, 24.8162285 ,
#        25.97872555, 25.56807711, 22.3213387 , 25.93157852, 25.84683548,
#        25.91369398, 23.51015368, 25.67126827, 23.29553671, 25.26786864,
# ...
